# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Enter any text :"))
# Out:
# Enter any text :Hi! Hello

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install speechRecongnition pydub
# Out:
# ERROR: Could not find a version that satisfies the requirement speechRecongnition (from versions: none)
# ERROR: No matching distribution found for speechRecongnition

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8047cdf673cc> in <cell line: 0>()
# ----> 1 a = gTTS(input("Enter any text:"))
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...

# %%
# !pip install speechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 30.0 MB/s eta 0:00:00
# ...

# %%
from pydub import AudioSegment
#mp3
mp3_file = "/content/WhatsApp Ptt 2025-05-20 at 10.24.11 AM (online-audio-converter.com).mp3"
wav_file = "/content/WhatsApp Ptt 2025-05-20 at 10.24.11 AM (online-audio-converter.com).wav"
audio = AudioSegment.from_mp3(mp3_file)
audio.export(wav_file, format="wav")
# Out:
# <_io.BufferedRandom name='/content/WhatsApp Ptt 2025-05-20 at 10.24.11 AM (online-audio-converter.com).wav'>

# %%
from os import ST_RDONLY
import speech recognition as sr
# Out:
#   File "<ipython-input-15-0ffe1e4edd37>", line 2
#     import speech recognition as sr
#                   ^
# SyntaxError: invalid syntax

# %%
import speech_recognition as sr
reco = sr.Recognizer()
with sr.AudioFile("/content/WhatsApp Ptt 2025-05-20 at 10.24.11 AM (online-audio-converter.com).wav") as source:
  audio_data = reco.record(source)
  print("Transcript: ",reco.recognize_goggle(audio_data))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-5019bac5d563> in <cell line: 0>()
#       3 with sr.AudioFile("/content/WhatsApp Ptt 2025-05-20 at 10.24.11 AM (online-audio-converter.com).wav") as source:
#       4   audio_data = reco.record(source)
# ----> 5   print("Transcript: ",reco.recognize_goggle(audio_data))
#
# AttributeError: 'Recognizer' object has no attribute 'recognize_goggle'

# %%
import speech_recognition as sr
reco = sr.Recognizer()
with sr.AudioFile("/content/WhatsApp Ptt 2025-05-20 at 10.24.11 AM (online-audio-converter.com).wav") as source:
  audio_data = reco.record(source)
  print("Transcript: ",reco.recognize_google(audio_data))
# Out:
# Transcript:  University

# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/WhatsApp Image 2025-05-20 at 11.21.33 AM.jpeg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(898.5), np.float64(1598.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text :",text)
# Out:
# Extracted text :
#
# import Speech aeeognition as Sa
#
# eco © Sy. Recognizer )
# with gr AudioFile (“Peontentlniholsopp ett
#
# ime
# 2085 -05-0% ot to. dy. I AM tonlin
# Wea com )yse0u ce Source +
#
# —audio- conver i
# le (audio—
#
# audio = dala en vecO Gite eg ne ey
#
# dato ))

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/WhatsApp Image 2025-05-20 at 11.39.25 AM.jpeg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(1279.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text :",text)
# Out:
# Extracted text : cslond ascodel otyle Sheet )
#
# web
#
# 5 seed to Sxlle a (eH Page
#
# crode upot electors & PlenerLoyee
#
# Al}
# A cleclrition consist Properly g Hs value
#
# Proper: value 5
#
# -) Tnline C¥
# 2) anlenol css
#
# css
#
# 3) & leno
#
# chiml >
# body >
# ce style c
#
# ‘aed ford —Sde- 3opx"> welcome .

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/WhatsApp Image 2025-05-20 at 11.43.29 AM.jpeg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(719.5), np.float64(1279.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text :",text)
# Out:
# Extracted text : fe ieee E1L.0
# € 00m MORE
# TAM anaes

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/birthday.jpg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1616.5), np.float64(2294.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text :",text)
# Out:
# Extracted text :
#
# May All yeor wishes
#
# COWMe Crue.
#
# May Ehe joe oheaol
#
#
#
#
#
# brings ee happiness
# fe ound pacapemE |

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/birthday 111.jpg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(685.5), np.float64(385.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text :",text)
# Out:
# Extracted text : Happy Birthday Wishes —_——
# Sending you a ig birth,
# hug and. lots of ae
#
# May your day be as owes®
# Happy Birthdos
#
# ac oul oLe.

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/WhatsApp Image 2025-05-20 at 11.53.02 AM.jpeg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(719.5), np.float64(1279.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text :",text)
# Out:
# Extracted text :
#
# Hopp y Birthday ilishes
#
#
#
# Sending YOU a big ‘thd
#
# hug ond lots of en Ce
#
# oe your day be os OUEST
# j Happy pithded
#
# As you ave

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/handwriting.jpg"
plt.imshow(Image.open(ip))
plt.axis('off')

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted text :",text)
# Out:
# Extracted text :

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Enter any text :"))

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/handwriting.jpg"
plt.imshow(Image.open(ip))
plt.axis('off')

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 2.2 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=2714f165e0fd95318f8a3239a80306e0a7b02a9d4efba6ed168107829f955d60
#   Stored in directory: /root/.cache/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# ...
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 6.1.0
# ...

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text :")
translated = t.translate(text,src= 'en',dest='telugu')
print("Translated text:",translated.text)
# Out:
# Enter a text :Dear students,  Keeping discipline and security point of view , none of the hostel  students are allowed to  violate the discipline rules framed  by  University and Hostel authorities.  If any of such violation is observed, they will be rusticated  from hostel permanently by calling parents which will be followed  by issuing of  TC .  If any daysscholars are involved in such activities,  strict disciplinary action will be taken immediately that even lead to issuing of TC.  Dean Student Affairs
# ...
