# %%
from transformers import pipeline

# %%
image_captioner = pipeline("image-to-text",)
# Out:
# No model was supplied, defaulted to ydshieh/vit-gpt2-coco-en and revision 5bebf1e (https://huggingface.co/ydshieh/vit-gpt2-coco-en).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.34k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/982M [00:00<?, ?B/s]
# ...

# %%
pipeline("image-to-text",model ='salesforce/blip-image-captioning-large',device=0)
# Out:
# config.json:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Device set to use cpu

# %%
image = r'/content/pecocok.jpg'
caption = image_captioner(image)
caption[0].get('generated_text')
# Out:
# 'a blue and white bird with a blue stripe on its head '

# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Enter any text :"))
# Out:
# Enter any text :a blue and white bird with a blue stripe on its head

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
vqa = pipeline('visual-question-answering')
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision d0a1f6a (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/136k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/470M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/470M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# Device set to use cpu

# %%
image = r'/content/pecocok.jpg'

# %%
q = input('Ask a question about the image:')
result = vqa(image,q)
result
# Out:
# Ask a question about the image:what is there in picture
# [{'score': 0.966347336769104, 'answer': 'peacock'},
#  {'score': 0.28160831332206726, 'answer': 'bird'},
#  {'score': 0.06931178271770477, 'answer': 'duck'},
#  {'score': 0.056639738380908966, 'answer': 'yes'},
#  {'score': 0.04167921468615532, 'answer': 'turkey'}]

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.8 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=9f781fb5c67891b470079899cb7a592f34511f9f11822dfce63311e8ff1824ce
#   Stored in directory: /root/.cache/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# ...
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 6.1.0
# ...

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text :")
translated = t.translate(text,src= 'en',dest='telugu')
print("Translated text:",translated.text)
# Out:
# Enter a text :a blue and white bird with a blue stripe on its head
# Translated text: నీలం మరియు తెలుపు పక్షి దాని తలపై నీలం గీతతో

# %%
from transformers import pipeline
img_cls = pipeline("image-classification")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 3f49326 (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# ...

# %%
img = "/content/pecocok.jpg"

# %%
r = img_cls(img)
r
# Out:
# [{'label': 'peacock', 'score': 0.9972715973854065},
#  {'label': 'black grouse', 'score': 9.535525896353647e-05},
#  {'label': 'partridge', 'score': 8.843183604767546e-05},
#  {'label': 'coucal', 'score': 8.501090633217245e-05},
#  {'label': 'prairie chicken, prairie grouse, prairie fowl',
#   'score': 7.25801000953652e-05}]

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 45.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.1 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=9d94ef28c3a9c647eba128317915c46f0465f33d89d2505866269bf5cdc31123
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
# !pip install deepface librosa speechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 57.5 MB/s eta 0:00:00
# ...

# %%
from deepface import DeepFace
import librosa
import speech_recognition as sr
import numpy as np
# Out:
# 25-05-22 10:29:23 - Directory /root/.deepface has been created
# 25-05-22 10:29:23 - Directory /root/.deepface/weights has been created

# %%
emotions = ['happy','sad','netural','angry','fear','suprise']

# %%
r = DeepFace.analyze(img_path='/content/LLL.jpg',actions=['emotion'])
r[0]
# Out:
# 25-05-22 10:30:55 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 81.6MB/s]
# {'emotion': {'angry': np.float32(0.0063696),
#   'disgust': np.float32(4.6155026e-09),
#   'fear': np.float32(94.80764),
#   'happy': np.float32(5.1501303),
#   'sad': np.float32(0.0020523092),
#   'surprise': np.float32(0.033790275),
#   'neutral': np.float32(1.6123773e-05)},
#  'dominant_emotion': 'fear',
#  'region': {'x': 107,
#   'y': 10,
#   'w': 91,
#   'h': 91,
#   'left_eye': None,
#   'right_eye': None},
#  'face_confidence': np.float64(0.95)}
